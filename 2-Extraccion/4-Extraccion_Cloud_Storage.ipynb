# %% [markdown]
# # Extracción de datos desde almacenamiento en la nube

# %% [markdown]
# ## Google Cloud Storage

# %% [markdown]
# Detalles de consumo en Cloud Storage
#
# - 5 GB mes de almacenamiento regional (solo en regiones de EE.UU.)
# - 5,000 operaciones de clase A por mes
# - 50,000 operaciones de clase B por mes
# - Salida de red de 1 GB por mes desde Norteamérica hacia todas las regiones de destino (excepto China y Australia)
#
# El nivel gratuito solo está disponible en las regiones **us-east1**, **us-west1** y **us-central1**. Los cálculos de uso se combinan en esas regiones.
#
# Documentacion
#
# https://cloud.google.com/python/docs/reference/storage/latest

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
from google.cloud import storage
import gcsfs
import os
import polars as pl

# %% [markdown]
# ~~~bash
# pip install google-cloud-storage
# ~~~

# %%
client = storage.Client.from_service_account_json('secretos/credentials.json')
for bucket in client.list_buckets():
    print(bucket.name)
# Out:
# data-hist-cf
# reportes-powerbi

# %%
for blob in client.get_bucket('data-hist-cf').list_blobs():
    print(blob.name)
# Out:
# DMS_data_gen (1).csv
# DMS_data_gen (2).csv
# DMS_data_gen (3).csv
# DMS_data_gen (4).csv
# DMS_data_gen (5).csv
# DMS_data_gen (6).csv
# DMS_data_gen.csv
# dlt/
# dlt/delta-table-mkt
# dlt/deltamkt.parquet

# %%
csv = client.get_bucket('data-hist-cf').get_blob('DMS_data_gen.csv')
csv.download_as_text()
# Out:
# 'Order_ID,Order_Date,Ship_Date,Ship_Mode,Country_Region,City,State_Province,Postal_Code,Customer_Name,Product_Name,Quantity,Discount\n593493,2018-02-25,18,First Class,United States,Newark,New Jersey,07195,Ken Black,Case Logic 2.4GHz Wireless Keyboard,65,0.69\n245840,2018-07-29,3,Second Class,United States,Peoria,Arizona,85383,Craig Leslie,DAX Value U-Channel Document Frames,2,0.47\n418194,2018-07-16,26,Second Class,Canada,Fermont,Québec,J1E,David Wiener,End Table,14,0.26\n520755,2018-06-24,19,First Class,Canada,Princeville,Québec,J1J,Rick Hansen,Colored Envelopes,52,0.07\n254624,2018-07-17,13,Second Class,United States,Denton,Texas,76205,Tom Stivers,Acme Kleen Earth Office Shears,48,0.54\n948270,2018-07-31,10,Second Class,Mexico,Las Flores,Tamaulipas,87395,Phillina Ober,Avery 49,28,0.63\n922829,2018-02-17,23,Standard Class,Canada,Stonewall,Manitoba,H9J,Tim Brockman,19w x 6d x 43h,28,0.32\n335157,2018-05-10,12,Standard Class,Mexico,Buenavista,Oaxaca,71730,Henry MacAllister,Eldon Shelf Savers Cubes and Bins,10,0.14\n404484,2018-07-16,2,Standard Class,Mexico,Independencia,Guanajuato,38260,Trudy Glocke,Satellite Sectional Post Binders,18,0.4\n523545,2018-02-04,17,Expedited,Mexico,Guadalupe,Veracruz Llave,94590,Erin Ashbrook,Xerox 1978,95,0.38\n916238,2018-12-04,26,Standard Class,Mexico,Francisco I Madero,Chiapas,30853,Steven Cartwright,Staple remover,52,0.56\n736215,2018-05-07,4,Second Class,Mexico,Benito Juarez,Chihuahua,31540,Thea Hudgings,Things To Do Today Spiral Book,55,0.35\n737861,2018-09-28,24,Standard Class,United States,Phoenix,Arizona,85053,Bobby Odegard,Hunt BOSTON Vista Battery-Operated Pencil Sharpener,85,0.34\n28368,2018-12-06,14,Second Class,United States,Rochester,New York,14683,Thea Hendricks,Xerox 1990,18,0.43\n443618,2018-04-02,15,First Class,United States,Washington,District of Columbia,20022,Julia Barnett,6/Carton,81,0.55\n676921,2018-06-30,20,First Class,Canada,Irricana,Alberta,B3T,Brenda Bowman,Eldon Simplefile Box Office,78,0.6\n693428,2018-10-17,29,Standard Class,United States,Toledo,Ohio,43666,Maria Zettner,Airmail Envelopes,26,0.47\n847443,2018-05-18,15,Standard Class,Canada,Cochrane,Alberta,T4C,Nona Balk,Standard Lip,23,0.42\n475208,2018-08-17,28,Second Class,United States,Scottsdale,Arizona,85271,Stefanie Holloman,Wilson Jones Century Plastic Molded Ring Binders,58,0.03\n32610,2018-12-09,21,Standard Class,Canada,Bridgewater,Nova Scotia,B4V,Liz Carlisle,Newell 321,13,0.66\n548006,2018-06-17,7,First Class,Canada,Oshawa,Ontario,L1K,Toby Gnade,Nu-Dell Leatherette Frames,98,0.62\n264549,2018-06-09,8,First Class,Mexico,San Isidro,Durango,35156,Dave Poirier,Portable Personal File Box,49,0.56\n438289,2018-08-27,18,Expedited,Canada,Mont-Royal,Québec,H5B,Dorris liebe,Newell 350,1,0.2\n785019,2018-10-30,18,Second Class,Mexico,Tierra Blanca,Guerrero,40678,Tracy Poddar,12/Pack,84,0.06\n586092,2018-08-17,15,First Class,Mexico,Morelos,Michoacan De Ocampo,61609,Mark Cousins,Barricks 18 x 48 Non-Folding Utility Table with Bottom Storage Shelf,53,0.18\n448631,2018-07-19,20,Standard Class,United States,Corona,California,92883,Liz Preis,Acme Design Line 8 Stainless Steel Bent Scissors w/Champagne Handles,88,0.3\n59612,2018-04-16,15,Standard Class,Mexico,Cuauhtemoc,Tamaulipas,87426,Roy Collins,Catalog Binders with Expanding Posts,36,0.46\n115057,2018-07-08,8,First Class,Canada,Kentville,Nova Scotia,B4N,Nicole Brennan,unpunched,19,0.61\n98310,2018-03-20,19,First Class,United States,Odessa,Texas,79764,Darrin Van Huff,Chisel Tip,63,0.46\n853045,2018-08-14,10,First Class,Mexico,San Jose,Guerrero,39266,Bart Folk,Side-Loading,18,0.68\n609705,2018-10-07,28,Second Class,United States,Chattanooga,Tennessee,37416,Janet Molinari,X-Base,32,0.56\n915793,2018-07-15,24,Expedited,Canada,Neepawa,Manitoba,H3Z,Denny Blanton,OSullivan Elevations Bookcase,94,0.63\n299156,2018-06-24,10,First Class,Canada,Rosthern,Saskatchewan,B0L,Stefanie Holloman,Sharp 1540cs Digital Laser Copier,94,0.38\n921517,2018-01-22,30,Second Class,Canada,Vaughan,Ontar ...

# %%
csv.download_to_filename('source/DMS_data_gen2.csv')

# %%
pd.read_csv('source/DMS_data_gen2.csv').head()
# Out:
#    Order_ID  Order_Date  Ship_Date     Ship_Mode Country_Region         City  \
# 0    593493  2018-02-25         18   First Class  United States       Newark
# 1    245840  2018-07-29          3  Second Class  United States       Peoria
# 2    418194  2018-07-16         26  Second Class         Canada      Fermont
# 3    520755  2018-06-24         19   First Class         Canada  Princeville
# 4    254624  2018-07-17         13  Second Class  United States       Denton
#
#   State_Province Postal_Code Customer_Name  \
# 0     New Jersey       07195     Ken Black
# 1        Arizona       85383  Craig Leslie
# 2         Québec         J1E  David Wiener
# 3         Québec         J1J   Rick Hansen
# 4          Texas       76205   Tom Stivers
#
#                           Product_Name  Quantity  Discount
# 0  Case Logic 2.4GHz Wireless Keyboard        65      0.69
# 1  DAX Value U-Channel Document Frames         2      0.47
# 2                            End Table        14      0.26
# 3                    Colored Envelopes        52      0.07
# 4       Acme Kleen Earth Office Shears        48      0.54

# %% [markdown]
# ### Lectura de datos desde Google Cloud Storage utilizando gcsfs y pandas

# %% [markdown]
# ~~~bash
# pip install gcsfs
# ~~~

# %% [markdown]
# ![bucket](../Images/bucket.png)

# %%
cv_path = 'gs://data-hist-cf/DMS_data_gen.csv'
pd.read_csv(
    cv_path,
    storage_options={'token':'secretos/credentials.json'}
).head()
# Out:
#    Order_ID  Order_Date  Ship_Date     Ship_Mode Country_Region         City  \
# 0    593493  2018-02-25         18   First Class  United States       Newark
# 1    245840  2018-07-29          3  Second Class  United States       Peoria
# 2    418194  2018-07-16         26  Second Class         Canada      Fermont
# 3    520755  2018-06-24         19   First Class         Canada  Princeville
# 4    254624  2018-07-17         13  Second Class  United States       Denton
#
#   State_Province Postal_Code Customer_Name  \
# 0     New Jersey       07195     Ken Black
# 1        Arizona       85383  Craig Leslie
# 2         Québec         J1E  David Wiener
# 3         Québec         J1J   Rick Hansen
# 4          Texas       76205   Tom Stivers
#
#                           Product_Name  Quantity  Discount
# 0  Case Logic 2.4GHz Wireless Keyboard        65      0.69
# 1  DAX Value U-Channel Document Frames         2      0.47
# 2                            End Table        14      0.26
# 3                    Colored Envelopes        52      0.07
# 4       Acme Kleen Earth Office Shears        48      0.54

# %% [markdown]
# ## Amazon S3

# %%
import pandas as pd

# Credenciales de AWS (ejemplo)
aws_credentials = {
    "key": "TU_CLAVE_DE_ACCESO_AWS",
    "secret": "TU_CLAVE_SECRETA_AWS",
    "token": "TU_TOKEN_DE_SESIÓN_AWS"  # Opcional, necesario en algunos casos
}

# Leer un archivo CSV desde S3
df = pd.read_csv("s3://nombre-de-tu-bucket/ruta/al/archivo.csv", storage_options=aws_credentials)

# Procesar el DataFrame como de costumbre
print(df.head())

# %% [markdown]
# ## Documentación de la función `storage_options` en `pd.read_csv` para consumir archivos de almacenamiento en la nube
#
# **Descripción**
#
# El parámetro `storage_options` en la función `pd.read_csv` de Pandas permite especificar opciones de configuración adicionales para leer archivos CSV directamente desde servicios de almacenamiento en la nube como Amazon S3 o Google Cloud Storage. Esto elimina la necesidad de descargar manualmente los archivos a tu máquina local antes de procesarlos con Pandas.
#
# **Uso**
#
# ```python
# import pandas as pd
#
# # Credenciales de AWS (ejemplo)
# aws_credentials = {
#     "key": "TU_CLAVE_DE_ACCESO_AWS",
#     "secret": "TU_CLAVE_SECRETA_AWS",
#     "token": "TU_TOKEN_DE_SESIÓN_AWS"  # Opcional, necesario en algunos casos
# }
#
# # Leer un archivo CSV desde S3
# df = pd.read_csv("s3://nombre-de-tu-bucket/ruta/al/archivo.csv", storage_options=aws_credentials)
#
# # Procesar el DataFrame como de costumbre
# print(df.head())
# ```
#
# **Parámetros**
#
# * `storage_options`: Un diccionario que contiene las opciones de configuración específicas del servicio de almacenamiento en la nube que estás utilizando. Las claves y valores exactos dependerán del servicio.
#
# **Ejemplos de configuración**
#
# * **Amazon S3**
#
# ```python
# aws_credentials = {
#     "key": "TU_CLAVE_DE_ACCESO_AWS",
#     "secret": "TU_CLAVE_SECRETA_AWS",
#     "token": "TU_TOKEN_DE_SESIÓN_AWS"  # Opcional
# }
# ```
#
# * **Google Cloud Storage**
#
# ```python
# gcs_credentials = {
#     "project_id": "TU_ID_DE_PROYECTO_GCP",
#     "token": "ruta/a/tu/archivo/de/credenciales.json"
# }
# ```
#
# **Notas importantes**
#
# * **Dependencias:** Asegúrate de tener instaladas las bibliotecas necesarias para interactuar con el servicio de almacenamiento en la nube que estás utilizando (por ejemplo, `boto3` para S3, `google-cloud-storage` para Google Cloud Storage).
# * **Formato del archivo:** El archivo CSV en la nube debe seguir el formato estándar que Pandas espera.
# * **Autenticación:** Proporciona las credenciales de autenticación adecuadas en el diccionario `storage_options`.
# * **Rendimiento:** Leer archivos directamente desde la nube puede ser más lento que leerlos localmente, especialmente para archivos muy grandes. Considera descargar archivos grandes localmente si el rendimiento es crítico.
#
# **Ventajas**
#
# * **Acceso directo a datos en la nube:** No es necesario descargar archivos manualmente.
# * **Flujo de trabajo simplificado:** Integración directa con Pandas para análisis de datos.
# * **Escalabilidad:** Capacidad para manejar grandes conjuntos de datos almacenados en la nube.
#
# **Limitaciones**
#
# * **Dependencia de bibliotecas externas:** Necesitas instalar y configurar las bibliotecas adecuadas para cada servicio de almacenamiento.
# * **Posible impacto en el rendimiento:** La lectura de archivos desde la nube puede ser más lenta que la lectura local.

# %% [markdown]
# # Polars

# %%
credentials = 'secretos/credentials.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials

fs = gcsfs.GCSFileSystem()
source = 'gs://data-hist-cf/DMS_data_gen.csv'
pl.read_csv(
    source,
    storage_options={'fs': fs}
).head()
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_18052\1276309544.py:10: UserWarning: Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.
#   pl.read_csv(
# shape: (5, 12)
# ┌──────────┬────────────┬───────────┬────────────┬───┬───────────┬───────────┬──────────┬──────────┐
# │ Order_ID ┆ Order_Date ┆ Ship_Date ┆ Ship_Mode  ┆ … ┆ Customer_ ┆ Product_N ┆ Quantity ┆ Discount │
# │ ---      ┆ ---        ┆ ---       ┆ ---        ┆   ┆ Name      ┆ ame       ┆ ---      ┆ ---      │
# │ i64      ┆ str        ┆ i64       ┆ str        ┆   ┆ ---       ┆ ---       ┆ i64      ┆ f64      │
# │          ┆            ┆           ┆            ┆   ┆ str       ┆ str       ┆          ┆          │
# ╞══════════╪════════════╪═══════════╪════════════╪═══╪═══════════╪═══════════╪══════════╪══════════╡
# │ 593493   ┆ 2018-02-25 ┆ 18        ┆ First      ┆ … ┆ Ken Black ┆ Case      ┆ 65       ┆ 0.69     │
# │          ┆            ┆           ┆ Class      ┆   ┆           ┆ Logic     ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ 2.4GHz    ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Wireless  ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Key…      ┆          ┆          │
# │ 245840   ┆ 2018-07-29 ┆ 3         ┆ Second     ┆ … ┆ Craig     ┆ DAX Value ┆ 2        ┆ 0.47     │
# │          ┆            ┆           ┆ Class      ┆   ┆ Leslie    ┆ U-Channel ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Document  ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ F…        ┆          ┆          │
# │ 418194   ┆ 2018-07-16 ┆ 26        ┆ Second     ┆ … ┆ David     ┆ End Table ┆ 14       ┆ 0.26     │
# │          ┆            ┆           ┆ Class      ┆   ┆ Wiener    ┆           ┆          ┆          │
# │ 520755   ┆ 2018-06-24 ┆ 19        ┆ First      ┆ … ┆ Rick      ┆ Colored   ┆ 52       ┆ 0.07     │
# │          ┆            ┆           ┆ Class      ┆   ┆ Hansen    ┆ Envelopes ┆          ┆          │
# │ 254624   ┆ 2018-07-17 ┆ 13        ┆ Second     ┆ … ┆ Tom       ┆ Acme      ┆ 48       ┆ 0.54     │
# │          ┆            ┆           ┆ Class      ┆   ┆ Stivers   ┆ Kleen     ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Earth     ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Office    ┆          ┆          │
# │          ┆            ┆           ┆            ┆   ┆           ┆ Shears    ┆          ┆          │
# └──────────┴────────────┴───────────┴────────────┴───┴───────────┴───────────┴──────────┴──────────┘
